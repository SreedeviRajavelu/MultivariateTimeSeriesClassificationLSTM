# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/raw_data_ppg_gsr/readme.txt
# /kaggle/input/raw_data_ppg_gsr/7/7/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/7/7/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/7/7/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/7/7/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/7/7/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/7/7/camera.csv
# /kaggle/input/raw_data_ppg_gsr/47/47/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/47/47/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/47/47/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/47/47/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/47/47/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/47/47/camera.csv
# /kaggle/input/raw_data_ppg_gsr/19/19/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/19/19/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/19/19/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/19/19/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/19/19/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/19/19/camera.csv
# /kaggle/input/raw_data_ppg_gsr/22/22/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/22/22/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/22/22/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/22/22/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/22/22/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/22/22/camera.csv
# /kaggle/input/raw_data_ppg_gsr/2/2/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/2/2/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/2/2/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/2/2/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/2/2/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/2/2/camera.csv
# /kaggle/input/raw_data_ppg_gsr/35/35/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/35/35/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/35/35/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/35/35/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/35/35/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/35/35/camera.csv
# /kaggle/input/raw_data_ppg_gsr/50/50/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/50/50/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/50/50/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/50/50/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/50/50/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/50/50/camera.csv
# /kaggle/input/raw_data_ppg_gsr/23/23/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/23/23/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/23/23/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/23/23/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/23/23/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/23/23/camera.csv
# /kaggle/input/raw_data_ppg_gsr/10/10/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/10/10/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/10/10/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/10/10/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/10/10/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/10/10/camera.csv
# /kaggle/input/raw_data_ppg_gsr/5/5/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/5/5/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/5/5/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/5/5/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/5/5/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/5/5/camera.csv
# /kaggle/input/raw_data_ppg_gsr/61/61/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/61/61/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/61/61/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/61/61/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/61/61/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/61/61/camera.csv
# /kaggle/input/raw_data_ppg_gsr/36/36/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/36/36/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/36/36/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/36/36/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/36/36/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/36/36/camera.csv
# /kaggle/input/raw_data_ppg_gsr/20/20/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/20/20/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/20/20/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/20/20/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/20/20/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/20/20/camera.csv
# /kaggle/input/raw_data_ppg_gsr/45/45/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/45/45/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/45/45/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/45/45/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/45/45/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/45/45/camera.csv
# /kaggle/input/raw_data_ppg_gsr/60/60/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/60/60/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/60/60/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/60/60/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/60/60/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/60/60/camera.csv
# /kaggle/input/raw_data_ppg_gsr/64/64/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/64/64/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/64/64/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/64/64/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/64/64/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/64/64/camera.csv
# /kaggle/input/raw_data_ppg_gsr/41/41/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/41/41/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/41/41/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/41/41/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/41/41/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/41/41/camera.csv
# /kaggle/input/raw_data_ppg_gsr/39/39/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/39/39/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/39/39/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/39/39/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/39/39/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/39/39/camera.csv
# /kaggle/input/raw_data_ppg_gsr/32/32/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/32/32/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/32/32/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/32/32/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/32/32/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/32/32/camera.csv
# /kaggle/input/raw_data_ppg_gsr/25/25/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/25/25/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/25/25/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/25/25/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/25/25/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/25/25/camera.csv
# /kaggle/input/raw_data_ppg_gsr/42/42/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/42/42/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/42/42/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/42/42/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/42/42/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/42/42/camera.csv
# /kaggle/input/raw_data_ppg_gsr/52/52/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/52/52/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/52/52/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/52/52/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/52/52/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/52/52/camera.csv
# /kaggle/input/raw_data_ppg_gsr/75/75/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/75/75/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/75/75/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/75/75/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/75/75/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/75/75/camera.csv
# /kaggle/input/raw_data_ppg_gsr/8/8/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/8/8/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/8/8/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/8/8/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/8/8/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/8/8/camera.csv
# /kaggle/input/raw_data_ppg_gsr/38/38/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/38/38/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/38/38/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/38/38/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/38/38/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/38/38/camera.csv
# /kaggle/input/raw_data_ppg_gsr/12/12/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/12/12/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/12/12/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/12/12/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/12/12/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/12/12/camera.csv
# /kaggle/input/raw_data_ppg_gsr/55/55/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/55/55/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/55/55/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/55/55/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/55/55/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/55/55/camera.csv
# /kaggle/input/raw_data_ppg_gsr/49/49/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/49/49/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/49/49/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/49/49/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/49/49/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/49/49/camera.csv
# /kaggle/input/raw_data_ppg_gsr/62/62/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/62/62/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/62/62/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/62/62/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/62/62/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/62/62/camera.csv
# /kaggle/input/raw_data_ppg_gsr/53/53/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/53/53/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/53/53/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/53/53/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/53/53/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/53/53/camera.csv
# /kaggle/input/raw_data_ppg_gsr/70/70/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/70/70/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/70/70/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/70/70/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/70/70/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/70/70/camera.csv
# /kaggle/input/raw_data_ppg_gsr/34/34/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/34/34/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/34/34/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/34/34/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/34/34/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/34/34/camera.csv
# /kaggle/input/raw_data_ppg_gsr/18/18/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/18/18/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/18/18/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/18/18/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/18/18/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/18/18/camera.csv
# /kaggle/input/raw_data_ppg_gsr/79/79/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/79/79/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/79/79/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/79/79/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/79/79/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/79/79/camera.csv
# /kaggle/input/raw_data_ppg_gsr/65/65/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/65/65/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/65/65/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/65/65/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/65/65/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/65/65/camera.csv
# /kaggle/input/raw_data_ppg_gsr/67/67/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/67/67/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/67/67/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/67/67/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/67/67/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/67/67/camera.csv
# /kaggle/input/raw_data_ppg_gsr/78/78/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/78/78/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/78/78/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/78/78/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/78/78/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/78/78/camera.csv
# /kaggle/input/raw_data_ppg_gsr/28/28/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/28/28/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/28/28/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/28/28/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/28/28/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/28/28/camera.csv
# /kaggle/input/raw_data_ppg_gsr/66/66/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/66/66/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/66/66/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/66/66/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/66/66/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/66/66/camera.csv
# /kaggle/input/raw_data_ppg_gsr/56/56/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/56/56/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/56/56/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/56/56/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/56/56/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/56/56/camera.csv
# /kaggle/input/raw_data_ppg_gsr/72/72/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/72/72/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/72/72/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/72/72/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/72/72/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/72/72/camera.csv
# /kaggle/input/raw_data_ppg_gsr/26/26/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/26/26/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/26/26/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/26/26/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/26/26/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/26/26/camera.csv
# /kaggle/input/raw_data_ppg_gsr/74/74/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/74/74/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/74/74/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/74/74/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/74/74/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/74/74/camera.csv
# /kaggle/input/raw_data_ppg_gsr/15/15/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/15/15/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/15/15/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/15/15/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/15/15/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/15/15/camera.csv
# /kaggle/input/raw_data_ppg_gsr/69/69/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/69/69/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/69/69/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/69/69/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/69/69/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/69/69/camera.csv
# /kaggle/input/raw_data_ppg_gsr/77/77/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/77/77/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/77/77/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/77/77/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/77/77/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/77/77/camera.csv
# /kaggle/input/raw_data_ppg_gsr/43/43/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/43/43/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/43/43/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/43/43/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/43/43/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/43/43/camera.csv
# /kaggle/input/raw_data_ppg_gsr/71/71/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/71/71/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/71/71/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/71/71/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/71/71/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/71/71/camera.csv
# /kaggle/input/raw_data_ppg_gsr/1/1/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/1/1/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/1/1/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/1/1/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/1/1/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/1/1/camera.csv
# /kaggle/input/raw_data_ppg_gsr/58/58/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/58/58/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/58/58/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/58/58/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/58/58/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/58/58/camera.csv
# /kaggle/input/raw_data_ppg_gsr/59/59/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/59/59/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/59/59/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/59/59/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/59/59/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/59/59/camera.csv
# /kaggle/input/raw_data_ppg_gsr/30/30/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/30/30/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/30/30/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/30/30/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/30/30/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/30/30/camera.csv
# /kaggle/input/raw_data_ppg_gsr/14/14/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/14/14/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/14/14/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/14/14/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/14/14/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/14/14/camera.csv
# /kaggle/input/raw_data_ppg_gsr/76/76/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/76/76/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/76/76/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/76/76/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/76/76/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/76/76/camera.csv
# /kaggle/input/raw_data_ppg_gsr/57/57/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/57/57/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/57/57/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/57/57/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/57/57/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/57/57/camera.csv
# /kaggle/input/raw_data_ppg_gsr/9/9/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/9/9/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/9/9/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/9/9/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/9/9/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/9/9/camera.csv
# /kaggle/input/raw_data_ppg_gsr/46/46/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/46/46/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/46/46/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/46/46/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/46/46/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/46/46/camera.csv
# /kaggle/input/raw_data_ppg_gsr/21/21/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/21/21/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/21/21/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/21/21/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/21/21/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/21/21/camera.csv
# /kaggle/input/raw_data_ppg_gsr/44/44/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/44/44/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/44/44/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/44/44/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/44/44/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/44/44/camera.csv
# /kaggle/input/raw_data_ppg_gsr/40/40/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/40/40/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/40/40/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/40/40/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/40/40/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/40/40/camera.csv
# /kaggle/input/raw_data_ppg_gsr/80/80/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/80/80/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/80/80/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/80/80/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/80/80/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/80/80/camera.csv
# /kaggle/input/raw_data_ppg_gsr/6/6/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/6/6/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/6/6/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/6/6/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/6/6/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/6/6/camera.csv
# /kaggle/input/raw_data_ppg_gsr/11/11/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/11/11/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/11/11/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/11/11/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/11/11/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/11/11/camera.csv
# /kaggle/input/raw_data_ppg_gsr/68/68/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/68/68/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/68/68/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/68/68/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/68/68/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/68/68/camera.csv
# /kaggle/input/raw_data_ppg_gsr/63/63/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/63/63/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/63/63/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/63/63/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/63/63/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/63/63/camera.csv
# /kaggle/input/raw_data_ppg_gsr/37/37/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/37/37/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/37/37/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/37/37/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/37/37/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/37/37/camera.csv
# /kaggle/input/raw_data_ppg_gsr/51/51/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/51/51/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/51/51/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/51/51/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/51/51/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/51/51/camera.csv
# /kaggle/input/raw_data_ppg_gsr/33/33/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/33/33/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/33/33/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/33/33/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/33/33/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/33/33/camera.csv
# /kaggle/input/raw_data_ppg_gsr/54/54/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/54/54/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/54/54/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/54/54/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/54/54/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/54/54/camera.csv
# /kaggle/input/raw_data_ppg_gsr/48/48/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/48/48/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/48/48/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/48/48/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/48/48/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/48/48/camera.csv
# /kaggle/input/raw_data_ppg_gsr/29/29/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/29/29/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/29/29/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/29/29/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/29/29/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/29/29/camera.csv
# /kaggle/input/raw_data_ppg_gsr/24/24/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/24/24/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/24/24/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/24/24/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/24/24/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/24/24/camera.csv
# /kaggle/input/raw_data_ppg_gsr/73/73/Arousal_Valence.csv
# /kaggle/input/raw_data_ppg_gsr/73/73/Panas.csv
# /kaggle/input/raw_data_ppg_gsr/73/73/raw_gsr.csv
# /kaggle/input/raw_data_ppg_gsr/73/73/raw_ppg.csv
# /kaggle/input/raw_data_ppg_gsr/73/73/Emotions.csv
# /kaggle/input/raw_data_ppg_gsr/73/73/camera.csv

# %% [markdown]
# # 2nd column is valence, 3rd column is arousal
#
# # 31 rows x 4 columns

# %%
sample_arousal_valence = pd.read_csv("/kaggle/input/raw_data_ppg_gsr/10/10/Arousal_Valence.csv")
# sample_arousal_valence = pd.read_csv("/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/10/10/Arousal_Valence.csv")
print(sample_arousal_valence)
# Out:
#     16  6  3  4
# 0   17  3  5  6
# 1   18  5  5  7
# 2   19  6  7  6
# 3   20  6  5  6
# 4   21  7  4  5
# 5   22  5  2  3
# 6   23  5  3  5
# 7    8  5  5  7
# 8    9  7  2  5
# 9   10  6  4  5
# 10  11  7  4  5
# 11  12  6  5  7
# 12  13  8  3  6
# 13  14  5  3  6
# 14  15  7  2  6
# 15  24  5  5  6
# 16  25  6  7  8
# 17  26  3  5  7
# 18  27  6  6  7
# 19  28  5  6  7
# 20  29  5  6  5
# 21  30  6  5  6
# 22  31  6  7  5
# 23   0  4  7  7
# 24   1  6  6  6
# 25   2  5  6  8
# 26   3  3  5  9
# 27   4  5  6  6
# 28   5  3  5  9
# 29   6  5  5  6
# 30   7  5  7  7

# %%
sample_arousal_valence.shape
# Out:
# (31, 4)

# %%
# import pandas as pd

# sample_raw_gsr = pd.read_csv('/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/10/10/raw_gsr.csv', delimiter=',', encoding='latin1')
# # print(sample_raw_ppg)
# pd.read_csv("/kaggle/input/raw_data_ppg_gsr/10/10/Arousal_Valence.csv")
# with open('/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/10/10/raw_gsr.csv', 'r') as file:
with open('/kaggle/input/raw_data_ppg_gsr/10/10/raw_gsr.csv', 'r') as file:
    for _ in range(5):
        print(file.readline())
        
# sample_raw_gsr = pd.read_csv('/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/10/10/raw_gsr.csv')
# Out:
# 1653098503514,167626.65625
#
# ,167471.5
#
# ,167102.015625
#
# ,166955.375
#
# 1653098504514,166100.59375

# %%
# with open('/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/10/10/raw_gsr.csv', 'r') as file:
with open('/kaggle/input/raw_data_ppg_gsr/10/10/raw_gsr.csv', 'r') as file:
    for i, line in enumerate(file):
        if 40 <= i <= 50:  # Print lines near the problematic line
            print(f"Line {i}: {line}")
# Out:
# Line 40: 1653098513514,160582.453125
#
# Line 41: ,161048.28125
#
# Line 42: ,161530.78125
#
# Line 43: ,161736.203125
#
# Line 44: 1653098514514,162662.21875,60
#
# Line 45: ,162934.453125
#
# Line 46: ,163200.359375
#
# Line 47: ,162932.984375
#
# Line 48: 1653098515514,161923.4375
#
# Line 49: ,160348.984375
#
# Line 50: ,158409.1875

# %%
# with open('/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/10/10/raw_gsr.csv', 'r') as file:
with open('/kaggle/input/raw_data_ppg_gsr/10/10/raw_gsr.csv', 'r') as file:
    for _ in range(55):
        print(file.readline())
# Out:
# 1653098503514,167626.65625
#
# ,167471.5
#
# ,167102.015625
#
# ,166955.375
#
# 1653098504514,166100.59375
#
# ,166128.859375
#
# ,165834.359375
#
# ,164697.875
#
# 1653098505514,162906.546875
#
# ,160625.859375
#
# ,157993.640625
#
# ,155868.5625
#
# 1653098506514,154536.578125
#
# ,153685.015625
#
# ,153312.03125
#
# ,153390.703125
#
# 1653098507514,153859.90625
#
# ,154674.765625
#
# ,155562.28125
#
# ,156477.078125
#
# 1653098508514,157111.984375
#
# ,157485.46875
#
# ,157590.515625
#
# ,157376.78125
#
# 1653098509514,156990.3125
#
# ,156641.3125
#
# ,156430.09375
#
# ,156397.296875
#
# 1653098510514,156580.859375
#
# ,158044.28125
#
# ,157763.8125
#
# ,157835.984375
#
# 1653098511514,158431.25
#
# ,159343.4375
#
# ,159119.765625
#
# ,160388.265625
#
# 1653098512514,160691.28125
#
# ,160694.125
#
# ,160889.1875
#
# ,160626.421875
#
# 1653098513514,160582.453125
#
# ,161048.28125
#
# ,161530.78125
#
# ,161736.203125
#
# 1653098514514,162662.21875,60
#
# ,162934.453125
#
# ,163200.359375
#
# ,162932.984375
#
# 1653098515514,161923.4375
#
# ,160348.984375
#
# ,158409.1875
#
# ,156600.25
#
# 1653098516514,155188.796875
#
# ,154266.671875
#
# ,153796.03125

# %%
# for gsr

# sample_raw_gsr = pd.read_csv(
#     '/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/10/10/raw_gsr.csv', 
#     names=['timestamp', 'gsr_value', 'extra_column'],  # Define expected columns
#     na_values=[''],  # Treat empty strings as NaN
#     skiprows=1  # Skip header if needed
# )

sample_raw_gsr = pd.read_csv(
    '/kaggle/input/raw_data_ppg_gsr/10/10/raw_gsr.csv', 
    names=['timestamp', 'gsr_value', 'extra_column'],  # Define expected columns
    na_values=[''],  # Treat empty strings as NaN
    skiprows=1  # Skip header if needed
)

# %%
print(sample_raw_gsr)
# Out:
#           timestamp      gsr_value  extra_column
# 0               NaN  167471.500000           NaN
# 1               NaN  167102.015625           NaN
# 2               NaN  166955.375000           NaN
# 3      1.653099e+12  166100.593750           NaN
# 4               NaN  166128.859375           NaN
# ...             ...            ...           ...
# 14682           NaN  158623.375000           NaN
# 14683  1.653102e+12  158737.984375           NaN
# 14684           NaN  159241.437500           NaN
# 14685           NaN  159396.109375           NaN
# 14686           NaN  159654.781250           NaN
#
# [14687 rows x 3 columns]

# %%
print(sample_raw_gsr['gsr_value'])

gsr_10 = sample_raw_gsr['gsr_value']
# Out:
# 0        167471.500000
# 1        167102.015625
# 2        166955.375000
# 3        166100.593750
# 4        166128.859375
#              ...
# 14682    158623.375000
# 14683    158737.984375
# 14684    159241.437500
# 14685    159396.109375
# 14686    159654.781250
# Name: gsr_value, Length: 14687, dtype: float64

# %%
print(gsr_10)
# Out:
# 0        167471.500000
# 1        167102.015625
# 2        166955.375000
# 3        166100.593750
# 4        166128.859375
#              ...
# 14682    158623.375000
# 14683    158737.984375
# 14684    159241.437500
# 14685    159396.109375
# 14686    159654.781250
# Name: gsr_value, Length: 14687, dtype: float64

# %%
gsr_10.shape
# Out:
# (14687,)

# %%
# for ppg

# sample_raw_ppg = pd.read_csv(
#    '/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/10/10/raw_ppg.csv', 
#     names=['timestamp', 'ppg_value', 'extra_column'],  # Define expected columns
#     na_values=[''],  # Treat empty strings as NaN
#     skiprows=1  # Skip header if needed
# )
sample_raw_ppg = pd.read_csv(
   '/kaggle/input/raw_data_ppg_gsr/10/10/raw_ppg.csv', 
    names=['timestamp', 'ppg_value', 'extra_column'],  # Define expected columns
    na_values=[''],  # Treat empty strings as NaN
    skiprows=1  # Skip header if needed
)
print(sample_raw_ppg['ppg_value'])
ppg_10 = sample_raw_ppg['ppg_value']
# Out:
# 0         956083.0
# 1         957633.0
# 2         959069.0
# 3         960354.0
# 4         961414.0
#             ...
# 348594    520632.0
# 348595    520862.0
# 348596    521081.0
# 348597    521116.0
# 348598    521097.0
# Name: ppg_value, Length: 348599, dtype: float64

# %%
ppg_10.shape
# Out:
# (348599,)

# %% [markdown]
# # Organize data as shown below :
#
# X_train :
#
# | subject_id | sequence_id | ppg_series | gsr_series |
# |------------|-------------|------------|------------|
# | 1          | 1           | [...]      | [...]      |
# | 1          | 2           | [...]      | [...]      |
# | 1          | 3           | [...]      | [...]      |
# | 2          | 1           | [...]      | [...]      |
# | 2          | 2           | [...]      | [...]      |
# | 2          | 3           | [...]      | [...]      |
#
#
# y_train :
#
# | subject_id | sequence_id | arousal | valence |
# |------------|-------------|---------|---------|
# | 1          | 1           | 7       | 6       |
# | 1          | 2           | 9       | 8       |
# | 1          | 3           | 4       | 5       |
# | 2          | 1           | 6       | 2       |
# | 2          | 2           | 8       | 4       |
# | 2          | 3           | 5       | 6       |

# %% [markdown]
# # Updated features_target dataframe
#
# | subject_id | series_id | ppg_series | gsr_series | Target |
# |------------|-----------|------------|------------|--------|
# | 1          | 1         | [...]      | [...]      | AxVy   |
# | 1          | 2         | [...]      | [...]      | AxVy   |
# | 1          | 3         | [...]      | [...]      | AxVy   |
# | 2          | 1         | [...]      | [...]      | AxVy   |
# | 2          | 2         | [...]      | [...]      | AxVy   |
# | 2          | 3         | [...]      | [...]      | AxVy   |

# %%
import os
import pandas as pd
import numpy as np

# Initialize an empty list to store data for each row
data = []

# Define the base directory
# base_dir = '/kaggle/input/raw-ppg-gsr-data-for-emotion-recognition/raw_data_ppg_gsr/'
base_dir = '/kaggle/input/raw_data_ppg_gsr/'

# Loop through each subject's subdirectory
for subject_folder in os.listdir(base_dir):
    subject_dir = os.path.join(base_dir, subject_folder, subject_folder)
    
    if os.path.isdir(subject_dir):  # Check if it’s a directory
        subject_id = int(subject_folder)  # Extract subject_id from folder name
        
        # Load raw_gsr.csv and raw_ppg.csv with specific column names
        raw_gsr_path = os.path.join(subject_dir, 'raw_gsr.csv')
        raw_ppg_path = os.path.join(subject_dir, 'raw_ppg.csv')
        
        # Define column names and load the data, treating empty strings as NaN and skipping the header row
        raw_gsr = pd.read_csv(
            raw_gsr_path, 
            names=['timestamp', 'gsr_value', 'extra_column'], 
            na_values=[''], 
            skiprows=1
        )['gsr_value']  # Select only the 'gsr_value' column

        raw_ppg = pd.read_csv(
            raw_ppg_path, 
            names=['timestamp', 'ppg_value', 'extra_column'], 
            na_values=[''], 
            skiprows=1
        )['ppg_value']  # Select only the 'ppg_value' column
        
        # Calculate downsampling factor
        gsr_downsample_factor = len(raw_gsr) // 6000
        ppg_downsample_factor = len(raw_ppg) // 6000
        
        # Downsample by taking every nth data point
        downsampled_gsr = raw_gsr.iloc[::gsr_downsample_factor].head(6000)
        downsampled_ppg = raw_ppg.iloc[::ppg_downsample_factor].head(6000)
        
        # Split the downsampled data into chunks of 200 for each row in the DataFrame
        gsr_chunks = np.array_split(downsampled_gsr.values.flatten(), 30)
        ppg_chunks = np.array_split(downsampled_ppg.values.flatten(), 30)
        
        # Load Arousal_Valence.csv for target labels
        av_path = os.path.join(subject_dir, 'Arousal_Valence.csv')
        av_data = pd.read_csv(av_path)

        for series_id in range(1, 31):  # For each of the 30 sequences per subject
            # Extract the chunk of 200 values for gsr_series and ppg_series
            gsr_series = gsr_chunks[series_id - 1]
            ppg_series = ppg_chunks[series_id - 1]
            
            # Create target label in "AxVy" format
            valence = int(av_data.iloc[series_id - 1, 1])  # Second column is Valence
            arousal = int(av_data.iloc[series_id - 1, 2])  # Third column is Arousal
            target = f"A{arousal}V{valence}"
            
            # Append the data to the list
            data.append({
                'subject_id': subject_id,
                'series_id': series_id,
                'ppg_series': ppg_series,
                'gsr_series': gsr_series,
                'target': target
            })

# Convert the list of dictionaries to a DataFrame
features_target = pd.DataFrame(data)

# Display the first few rows of the DataFrame
features_target.head()
# Out:
#    subject_id  series_id                                         ppg_series  \
# 0           7          1  [799777.0, 800031.0, 770530.0, 783136.0, 77184...
# 1           7          2  [782666.0, 781125.0, 786560.0, 793689.0, 79145...
# 2           7          3  [783222.0, 774507.0, 775848.0, 780017.0, 77640...
# 3           7          4  [631551.0, 644157.0, 663125.0, 658480.0, 65069...
# 4           7          5  [580910.0, 581498.0, 583054.0, 580285.0, 57964...
#
#                                           gsr_series target
# 0  [192276.21875, 192022.203125, 191918.46875, 21...   A4V6
# 1  [177154.21875, 177107.75, 177348.90625, 177485...   A2V7
# 2  [174372.71875, 174527.484375, 174541.609375, 1...   A3V3
# 3  [159124.453125, 159066.09375, 159165.1875, 159...   A3V6
# 4  [153937.34375, 154182.421875, 154383.625, 1544...   A4V8

# %%
# Function to categorize Arousal (A) and Valence (V)
def categorize_arousal_valence(target_value):
    # Extract the Arousal (Ax) and Valence (Vy) digits
    arousal_level = int(target_value[1])
    valence_level = int(target_value[3])
    
    # Determine arousal label
    if 1 <= arousal_level <= 3:
        arousal_label = 'L'
    elif 4 <= arousal_level <= 6:
        arousal_label = 'M'
    elif 7 <= arousal_level <= 9:
        arousal_label = 'H'
    
    # Determine valence label
    if 1 <= valence_level <= 3:
        valence_label = 'L'
    elif 4 <= valence_level <= 6:
        valence_label = 'M'
    elif 7 <= valence_level <= 9:
        valence_label = 'H'
    
    # Create the grouped target label
    return f"A{arousal_label}V{valence_label}"

# Apply the function to each row in the DataFrame
features_target['grouped_target'] = features_target['target'].apply(categorize_arousal_valence)

# Display the updated DataFrame
print(features_target)
# Out:
#       subject_id  series_id  \
# 0              7          1
# 1              7          2
# 2              7          3
# 3              7          4
# 4              7          5
# ...          ...        ...
# 2185          73         26
# 2186          73         27
# 2187          73         28
# 2188          73         29
# 2189          73         30
#
#                                              ppg_series  \
# 0     [799777.0, 800031.0, 770530.0, 783136.0, 77184...
# 1     [782666.0, 781125.0, 786560.0, 793689.0, 79145...
# 2     [783222.0, 774507.0, 775848.0, 780017.0, 77640...
# 3     [631551.0, 644157.0, 663125.0, 658480.0, 65069...
# 4     [580910.0, 581498.0, 583054.0, 580285.0, 57964...
# ...                                                 ...
# 2185  [905862.0, 926712.0, 930059.0, 927195.0, 92955...
# 2186  [960042.0, 961990.0, 975783.0, 971625.0, 97131...
# 2187  [925540.0, 937767.0, 924606.0, 918078.0, 93121...
# 2188  [991638.0, 999610.0, 990225.0, 987324.0, 10016...
# 2189  [909032.0, 900104.0, 899839.0, 885948.0, 87284...
#
#                                              gsr_series target grouped_target
# 0     [192276.21875, 192022.203125, 191918.46875, 21...   A4V6           AMVM
# 1     [177154.21875, 177107.75, 177348.90625, 177485...   A2V7           ALVH
# 2     [174372.71875, 174527.484375, 174541.609375, 1...   A3V3           ALVL
# 3     [159124.453125, 159066.09375, 159165.1875, 159...   A3V6           ALVM
# 4     [153937.34375, 154182.421875, 154383.625, 1544...   A4V8           AMVH
# ...                                                 ...    ...            ...
# 2185  [238785.265625, 238904.21875, 238830.90625, 23...   A2V6           ALVM
# 2186  [237746.59375, 238165.796875, 238321.421875, 2...   A5V3           AMVL
# 2187  [237603.84375, 237533.40625, 237408.0, 237196....   A3V7           ALVH
# 2188  [236993.34375, 236990.015625, 236776.75, 23674...   A5V5           AMVM
# 2189  [236165.0, 236153.046875, 235879.984375, 23607...   A1V5           ALVM
#
# [2190 rows x 6 columns]

# %%
features_target.shape
# Out:
# (2190, 6)

# %% [markdown]
# # List all unique subject_id values

# %%
unique_subject_ids = features_target['subject_id'].unique()
print(unique_subject_ids)
# Out:
# [ 7 47 19 22  2 35 50 23 10  5 61 36 20 45 60 64 41 39 32 25 42 52 75  8
#  38 12 55 49 62 53 70 34 18 79 65 67 78 28 66 56 72 26 74 15 69 77 43 71
#   1 58 59 30 14 76 57  9 46 21 44 40 80  6 11 68 63 37 51 33 54 48 29 24
#  73]

# %% [markdown]
# # Count of unique subject_id values

# %%
unique_subject_count = features_target['subject_id'].nunique()
print(unique_subject_count)
# Out:
# 73

# %% [markdown]
# # After preprocessing check that each subject id has the same number of sequence ids (value counts)

# %%
import os
import torch
import numpy as np
import pandas as pd
from tqdm.auto import tqdm

import torch
import torch.autograd as autograd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from matplotlib.ticker import MaxNLocator

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from multiprocessing import cpu_count

from sklearn.metrics import classification_report , confusion_matrix

# %% [markdown]
# # Preprocessing to convert string values of surfaces to integers for neural network

# %%
# USING NUMERIC VALUES OF AROUSAL & VALENCE AS IS

# label_encoder = LabelEncoder()
# encoded_labels = label_encoder.fit_transform(features_target.target)

# GROUPING NUMERIC VALUES BASED ON RANGES: 1-3, 4-6 AND 7-9
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(features_target.grouped_target)

# %%
encoded_labels
# Out:
# array([8, 3, 4, ..., 3, 8, 5])

# %%
#labels are stored in the classes_ property in label encoder
label_encoder.classes_
# to reverse transformation if and when needed
# Out:
# array(['AHVH', 'AHVL', 'AHVM', 'ALVH', 'ALVL', 'ALVM', 'AMVH', 'AMVL',
#        'AMVM'], dtype=object)

# %%
features_target['label']=encoded_labels

# %%
unique_labels_count = features_target['label'].nunique()
print(unique_labels_count)
# Out:
# 9

# %%
features_target.head()
# Out:
#    subject_id  series_id                                         ppg_series  \
# 0           7          1  [799777.0, 800031.0, 770530.0, 783136.0, 77184...
# 1           7          2  [782666.0, 781125.0, 786560.0, 793689.0, 79145...
# 2           7          3  [783222.0, 774507.0, 775848.0, 780017.0, 77640...
# 3           7          4  [631551.0, 644157.0, 663125.0, 658480.0, 65069...
# 4           7          5  [580910.0, 581498.0, 583054.0, 580285.0, 57964...
#
#                                           gsr_series target grouped_target  \
# 0  [192276.21875, 192022.203125, 191918.46875, 21...   A4V6           AMVM
# 1  [177154.21875, 177107.75, 177348.90625, 177485...   A2V7           ALVH
# 2  [174372.71875, 174527.484375, 174541.609375, 1...   A3V3           ALVL
# 3  [159124.453125, 159066.09375, 159165.1875, 159...   A3V6           ALVM
# 4  [153937.34375, 154182.421875, 154383.625, 1544...   A4V8           AMVH
#
#    label
# 0      8
# 1      3
# 2      4
# 3      5
# 4      6

# %%
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset

# Step 1: Initialize an empty list to store sequences and labels
sequences = []

# Step 2: Iterate through each row in features_target DataFrame to create sequence_features and add to sequences list
for _, row in features_target.iterrows():
    # Extract the first 200 values from ppg_series and gsr_series, assuming they are stored as arrays
    sequence_features = pd.DataFrame({
        'ppg_series': row['ppg_series'][:200],
        'gsr_series': row['gsr_series'][:200]
    })
    
    # Append (sequence_features, label) as a tuple to the sequences list
    sequences.append((sequence_features, row['label']))

# %% [markdown]
# train_sequences, test_sequences = train_test_split(sequences, test_size=0.2)
#
# len(train_sequences) , len(test_sequences)

# %%
# Step 3: Split into training and test sets
train_sequences, test_sequences = train_test_split(sequences, test_size=0.2)
len(train_sequences), len(test_sequences)
# Out:
# (1752, 438)

# %%
# Dataset class
class MixedEmotionDataset(Dataset): 
    def __init__(self, sequences):
        self.sequences = sequences
        
    def __len__(self):
        return len(self.sequences)
    
    def __getitem__(self, idx):
        sequence, label = self.sequences[idx]
        return dict(
            sequence=torch.Tensor(sequence.to_numpy()),  # Convert DataFrame to tensor
            label=torch.tensor(label).long()
        )

# %%
# MixedEmotionDataLoader for train, validation, and test DataLoaders
class MixedEmotionDataLoader:
    
    def __init__(self, train_sequences, test_sequences, batch_size):
        self.train_sequences = train_sequences
        self.test_sequences = test_sequences
        self.batch_size = batch_size
        self.setup()
        
    def setup(self):
        self.train_dataset = MixedEmotionDataset(self.train_sequences)
        self.test_dataset = MixedEmotionDataset(self.test_sequences)
        
    def get_train_loader(self):
        return DataLoader(
            self.train_dataset,
            batch_size=self.batch_size,
            shuffle=True,
            num_workers=cpu_count()
        )
    
    def get_val_loader(self):
        return DataLoader(
            self.test_dataset,
            batch_size=self.batch_size,
            shuffle=False,
            num_workers=cpu_count()
        )
    
    def get_test_loader(self):
        return DataLoader(
            self.test_dataset,
            batch_size=self.batch_size,
            shuffle=False,
            num_workers=cpu_count()
        )

# %% [markdown]
# # Model

# %%
class SequenceModel(nn.Module):
    # classification, number of hidden units, number of layers for LSTM
    
    def __init__(self, n_features, n_classes , n_hidden=256, n_layers=3):
        super().__init__()
        
        self.lstm = nn.LSTM(
        input_size = n_features,
        hidden_size=n_hidden,
        num_layers=n_layers,
        batch_first=True,
        dropout=0.75)
        
        self.classifier = nn.Linear(n_hidden , n_classes)
        
    def forward(self, x):
        self.lstm.flatten_parameters()
        _, (hidden, _) = self.lstm(x)
        
        out = hidden[-1]
        
        return self.classifier(out)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchmetrics import Accuracy
import matplotlib.pyplot as plt

class MixedEmotionPredictor(nn.Module): 
    def __init__(self, n_features: int, n_classes: int):
        super(MixedEmotionPredictor, self).__init__()
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = SequenceModel(n_features, n_classes).to(self.device)
        self.criterion = nn.CrossEntropyLoss()
        self.accuracy_metric = Accuracy(task='multiclass', num_classes=n_classes).to(self.device)
        
        # Initialize lists to store metrics for each epoch
        self.epoch_train_losses = []
        self.epoch_val_losses = []
        self.epoch_train_accuracies = []
        self.epoch_val_accuracies = []
        
    def forward(self, x):
        return self.model(x)
    
    def compute_loss_and_accuracy(self, outputs, labels):
        loss = self.criterion(outputs, labels)
        predictions = torch.argmax(outputs, dim=1)
        accuracy = self.accuracy_metric(predictions, labels)
        return loss, accuracy
        
    def plot_metrics(self):
        num_epochs = min(len(self.epoch_train_losses), len(self.epoch_val_losses))
        epochs = range(1, num_epochs + 1)
        
        train_losses = self.epoch_train_losses[:num_epochs]
        val_losses = self.epoch_val_losses[:num_epochs]
        train_accuracies = self.epoch_train_accuracies[:num_epochs]
        val_accuracies = self.epoch_val_accuracies[:num_epochs]
        
        plt.figure(figsize=(12, 5))
        
        # Plot Loss
        plt.subplot(1, 2, 1)
        plt.plot(epochs, train_losses, 'b', label='Training Loss')
        plt.plot(epochs, val_losses, 'r', label='Validation Loss')
        plt.title('Training and Validation Loss')
        plt.xlabel('Epochs')
        plt.ylabel('Loss')
        plt.legend()
        
        # Plot Accuracy
        plt.subplot(1, 2, 2)
        plt.plot(epochs, train_accuracies, 'b', label='Training Accuracy')
        plt.plot(epochs, val_accuracies, 'r', label='Validation Accuracy')
        plt.title('Training and Validation Accuracy')
        plt.xlabel('Epochs')
        plt.ylabel('Accuracy')
        plt.legend()
        
        plt.tight_layout()
        plt.show()
    
    def train_model(self, train_loader, val_loader, num_epochs=10, lr=0.0001):
        optimizer = optim.Adam(self.parameters(), lr=lr)

        for epoch in range(num_epochs):
            # Training phase
            self.train()
            train_losses = []
            train_accuracies = []

            for batch in train_loader:
                sequences = batch["sequence"].to(self.device)
                labels = batch["label"].to(self.device)

                optimizer.zero_grad()
                outputs = self(sequences)
                loss, accuracy = self.compute_loss_and_accuracy(outputs, labels)

                loss.backward()
                optimizer.step()

                train_losses.append(loss.item())
                train_accuracies.append(accuracy.item())

            avg_train_loss = sum(train_losses) / len(train_losses)
            avg_train_accuracy = sum(train_accuracies) / len(train_accuracies)

            # Validation phase
            self.eval()
            val_losses = []
            val_accuracies = []

            with torch.no_grad():
                for batch in val_loader:
                    sequences = batch["sequence"].to(self.device)
                    labels = batch["label"].to(self.device)

                    outputs = self(sequences)
                    loss, accuracy = self.compute_loss_and_accuracy(outputs, labels)

                    val_losses.append(loss.item())
                    val_accuracies.append(accuracy.item())

            avg_val_loss = sum(val_losses) / len(val_losses)
            avg_val_accuracy = sum(val_accuracies) / len(val_accuracies)

            # Store epoch metrics for plotting
            self.epoch_train_losses.append(avg_train_loss)
            self.epoch_val_losses.append(avg_val_loss)
            self.epoch_train_accuracies.append(avg_train_accuracy)
            self.epoch_val_accuracies.append(avg_val_accuracy)

            # Print metrics
            print(f"Epoch {epoch + 1}/{num_epochs}")
            print(f"  Training Loss: {avg_train_loss:.4f}, Training Accuracy: {avg_train_accuracy:.4f}")
            print(f"  Validation Loss: {avg_val_loss:.4f}, Validation Accuracy: {avg_val_accuracy:.4f}")

        # Plot training and validation metrics
        self.plot_metrics()

# %%
import torch
from torch.utils.tensorboard import SummaryWriter
import os

# Parameters
N_EPOCHS = 250
BATCH_SIZE = 64
CHECKPOINT_DIR = "checkpoints"
LOG_DIR = "lightning_logs/surface"
BEST_MODEL_PATH = os.path.join(CHECKPOINT_DIR, "best-checkpoint.pth")

# Ensure directories exist
os.makedirs(CHECKPOINT_DIR, exist_ok=True)

# Instantiate TensorBoard writer
writer = SummaryWriter(LOG_DIR)

# Function to save the model checkpoint
def save_checkpoint(model, optimizer, epoch, val_loss, best_val_loss):
    # Only save the model if the current val_loss is better than the best_val_loss
    if val_loss < best_val_loss:
        print(f"Validation loss improved from {best_val_loss:.4f} to {val_loss:.4f}. Saving model...")
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': val_loss,
        }, BEST_MODEL_PATH)
        return val_loss
    return best_val_loss

# Training loop
def train(model, train_loader, val_loader, criterion, optimizer):
    best_val_loss = float('inf')

    for epoch in range(1, N_EPOCHS + 1):
        model.train()
        train_loss = 0.0
        train_correct = 0
        train_total = 0
        
        # Training step
        for batch in train_loader:
            sequences, labels = batch["sequence"].to(model.device), batch["label"].to(model.device)
            optimizer.zero_grad()
            outputs = model(sequences)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * sequences.size(0)
            train_correct += (outputs.argmax(1) == labels).sum().item()
            train_total += labels.size(0)
        
        avg_train_loss = train_loss / train_total
        train_accuracy = train_correct / train_total
        
        # Validation step
        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for batch in val_loader:
                sequences, labels = batch["sequence"].to(model.device), batch["label"].to(model.device)
                outputs = model(sequences)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * sequences.size(0)
                val_correct += (outputs.argmax(1) == labels).sum().item()
                val_total += labels.size(0)
                
        avg_val_loss = val_loss / val_total
        val_accuracy = val_correct / val_total

        # Logging to TensorBoard
        writer.add_scalar("Loss/Train", avg_train_loss, epoch)
        writer.add_scalar("Loss/Validation", avg_val_loss, epoch)
        writer.add_scalar("Accuracy/Train", train_accuracy, epoch)
        writer.add_scalar("Accuracy/Validation", val_accuracy, epoch)

        # Print metrics
        print(f"Epoch {epoch}/{N_EPOCHS}, "
              f"Train Loss: {avg_train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, "
              f"Val Loss: {avg_val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")
        
        # Save metrics to model for plotting
        model.epoch_train_losses.append(avg_train_loss)
        model.epoch_train_accuracies.append(train_accuracy)
        model.epoch_val_losses.append(avg_val_loss)
        model.epoch_val_accuracies.append(val_accuracy)
        
        # Save checkpoint
        best_val_loss = save_checkpoint(model, optimizer, epoch, avg_val_loss, best_val_loss)

    writer.close()

# Example usage
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
n_features = 2  # using ppg_series and gsr_series features
n_classes = len(label_encoder.classes_)  # Replace with actual number of classes

# Initialize model, optimizer, and criterion
model = MixedEmotionPredictor(n_features=n_features, n_classes=n_classes).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
criterion = torch.nn.CrossEntropyLoss()

# Instantiate data loader
data_loader = MixedEmotionDataLoader(train_sequences, test_sequences, BATCH_SIZE)
train_loader = data_loader.get_train_loader()
val_loader = data_loader.get_val_loader()

# Train the model
train(model, train_loader, val_loader, criterion, optimizer)

# Plot metrics
model.plot_metrics()
# Out:
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch 1/250, Train Loss: 2.1593, Train Accuracy: 0.1952, Val Loss: 2.0401, Val Accuracy: 0.3288
# Validation loss improved from inf to 2.0401. Saving model...
# Epoch 2/250, Train Loss: 2.0131, Train Accuracy: 0.2705, Val Loss: 1.9015, Val Accuracy: 0.3288
# Validation loss improved from 2.0401 to 1.9015. Saving model...
# Epoch 3/250, Train Loss: 1.9603, Train Accuracy: 0.2705, Val Loss: 1.8973, Val Accuracy: 0.3288
# Validation loss improved from 1.9015 to 1.8973. Saving model...
# Epoch 4/250, Train Loss: 1.9506, Train Accuracy: 0.2705, Val Loss: 1.8983, Val Accuracy: 0.3288
# Epoch 5/250, Train Loss: 1.9508, Train Accuracy: 0.2705, Val Loss: 1.8994, Val Accuracy: 0.3288
# Epoch 6/250, Train Loss: 1.9494, Train Accuracy: 0.2705, Val Loss: 1.8961, Val Accuracy: 0.3288
# Validation loss improved from 1.8973 to 1.8961. Saving model...
# Epoch 7/250, Train Loss: 1.9481, Train Accuracy: 0.2705, Val Loss: 1.8968, Val Accuracy: 0.3288
# Epoch 8/250, Train Loss: 1.9472, Train Accuracy: 0.2705, Val Loss: 1.8920, Val Accuracy: 0.3288
# Validation loss improved from 1.8961 to 1.8920. Saving model...
# Epoch 9/250, Train Loss: 1.9463, Train Accuracy: 0.2705, Val Loss: 1.8956, Val Accuracy: 0.3288
# Epoch 10/250, Train Loss: 1.9391, Train Accuracy: 0.2654, Val Loss: 1.8886, Val Accuracy: 0.3288
# Validation loss improved from 1.8920 to 1.8886. Saving model...
# Epoch 11/250, Train Loss: 1.9423, Train Accuracy: 0.2711, Val Loss: 1.8891, Val Accuracy: 0.3288
# Epoch 12/250, Train Loss: 1.9427, Train Accuracy: 0.2694, Val Loss: 1.8996, Val Accuracy: 0.3242
# Epoch 13/250, Train Loss: 1.9380, Train Accuracy: 0.2688, Val Loss: 1.9081, Val Accuracy: 0.2991
# Epoch 14/250, Train Loss: 1.9380, Train Accuracy: 0.2648, Val Loss: 1.9006, Val Accuracy: 0.3128
# Epoch 15/250, Train Loss: 1.9368, Train Accuracy: 0.2671, Val Loss: 1.9008, Val Accuracy: 0.3128
# Epoch 16/250, Train Loss: 1.9379, Train Accuracy: 0.2705, Val Loss: 1.9119, Val Accuracy: 0.2877
# Epoch 17/250, Train Loss: 1.9385, Train Accuracy: 0.2666, Val Loss: 1.8962, Val Accuracy: 0.3288
# Epoch 18/250, Train Loss: 1.9340, Train Accuracy: 0.2700, Val Loss: 1.8968, Val Accuracy: 0.3265
# Epoch 19/250, Train Loss: 1.9334, Train Accuracy: 0.2648, Val Loss: 1.8934, Val Accuracy: 0.3288
# Epoch 20/250, Train Loss: 1.9363, Train Accuracy: 0.2717, Val Loss: 1.9035, Val Accuracy: 0.2831
# Epoch 21/250, Train Loss: 1.9376, Train Accuracy: 0.2711, Val Loss: 1.8973, Val Accuracy: 0.3288
# Epoch 22/250, Train Loss: 1.9346, Train Accuracy: 0.2688, Val Loss: 1.9053, Val Accuracy: 0.2694
# Epoch 23/250, Train Loss: 1.9376, Train Accuracy: 0.2620, Val Loss: 1.8973, Val Accuracy: 0.3288
# Epoch 24/250, Train Loss: 1.9369, Train Accuracy: 0.2683, Val Loss: 1.8912, Val Accuracy: 0.3288
# Epoch 25/250, Train Loss: 1.9348, Train Accuracy: 0.2694, Val Loss: 1.8968, Val Accuracy: 0.3288
# Epoch 26/250, Train Loss: 1.9342, Train Accuracy: 0.2671, Val Loss: 1.8959, Val Accuracy: 0.3219
# Epoch 27/250, Train Loss: 1.9293, Train Accuracy: 0.2666, Val Loss: 1.8959, Val Accuracy: 0.3196
# Epoch 28/250, Train Loss: 1.9299, Train Accuracy: 0.2711, Val Loss: 1.8992, Val Accuracy: 0.3151
# Epoch 29/250, Train Loss: 1.9310, Train Accuracy: 0.2711, Val Loss: 1.8933, Val Accuracy: 0.3014
# Epoch 30/250, Train Loss: 1.9352, Train Accuracy: 0.2700, Val Loss: 1.8977, Val Accuracy: 0.3288
# Epoch 31/250, Train Loss: 1.9373, Train Accuracy: 0.2705, Val Loss: 1.8982, Val Accuracy: 0.3288
# Epoch 32/250, Train Loss: 1.9285, Train Accuracy: 0.2734, Val Loss: 1.8931, Val Accuracy: 0.3288
# Epoch 33/250, Train Loss: 1.9310, Train Accuracy: 0.2683, Val Loss: 1.8937, Val Accuracy: 0.3288
# Epoch 34/250, Train Loss: 1.9288, Train Accuracy: 0.2694, Val Loss: 1.8937, Val Accuracy: 0.3288
# Epoch 35/250, Train Loss: 1.9252, Train Accuracy: 0.2700, Val Loss: 1.8962, Val Accuracy: 0.3196
# Epoch 36/250, Train Loss: 1.9245, Train Accuracy: 0.2677, Val Loss: 1.8918, Val Accuracy: 0.3288
# Epoch 37/250, Train Loss: 1.9254, Train Accuracy: 0.2694, Val Loss: 1.8942, Val Accuracy: 0.3288
# Epoch 38/250, Train Loss: 1.9304, Train Accuracy: 0.2723, Val Loss: 1.8941, Val Accuracy: 0.3082
# Epoch 39/250, Train Loss: 1.9278, Train Accuracy: 0.2654, Val Loss: 1.8925, Val Accuracy: 0.3288
# Epoch 40/250, Train Loss: 1.9275, Train Accuracy: 0.2654, Val Loss: 1.8979, Val Accuracy: 0.3219
# Epoch 41/250, Train Loss: 1.9278, Train Accuracy: 0.2700, Val Loss: 1.8972, Val Accuracy: 0.3288
# Epoch 42/250, Train Loss: 1.9279, Train Accuracy: 0.2740, Val Loss: 1.8981, Val Accuracy: 0.3288
# Epoch 43/250, Train Loss: 1.9290, Train Accuracy: 0.2671, Val Loss: 1.8891, Val Accuracy: 0.3288
# Epoch 44/250, Train Loss: 1.9277, Train Accuracy: 0.2705, Val Loss: 1.8911, Val Accuracy: 0.3333
# Epoch 45/250, Train Loss: 1.9244, Train Accuracy: 0.2648, Val Loss: 1.8917, Val Accuracy: 0.3288
# Epoch 46/250, Train Loss: 1.9243, Train Accuracy: 0.2677, Val Loss: 1.8910, Val Accuracy: 0.3288
# Epoch 47/250, Train Loss: 1.9203, Train Accuracy: 0.2740, Val Loss: 1.8915, Val Accuracy: 0.3242
# Epoch 48/250, Train Loss: 1.9263, Train Accuracy: 0.2734, Val Loss: 1.8930, Val Accuracy: 0.3288
# Epoch 49/250, Train Loss: 1.9203, Train Accuracy: 0.2740, Val Loss: 1.8995, Val Accuracy: 0.3265
# Epoch 50/250, Train Loss: 1.9277, Train Accuracy: 0.2745, Val Loss: 1.8965, Val Accuracy: 0.3265
# Epoch 51/250, Train Loss: 1.9219, Train Accuracy: 0.2688, Val Loss: 1.8970, Val Accuracy: 0.3219
# Epoch 52/250, Train Loss: 1.9251, Train Accuracy: 0.2711, Val Loss: 1.8957, Val Accuracy: 0.3242
# Epoch 53/250, Train Loss: 1.9233, Train Accuracy: 0.2700, Val Loss: 1.8996, Val Accuracy: 0.3196
# Epoch 54/250, Train Loss: 1.9214, Train Accuracy: 0.2711, Val Loss: 1.8933, Val Accuracy: 0.3242
# Epoch 55/250, Train Loss: 1.9189, Train Accuracy: 0.2660, Val Loss: 1.8979, Val Accuracy: 0.3242
# Epoch 56/250, Train Loss: 1.9175, Train Accuracy: 0.2780, Val Loss: 1.9028, Val Accuracy: 0.3288
# Epoch 57/250, Train Loss: 1.9203, Train Accuracy: 0.2751, Val Loss: 1.8912, Val Accuracy: 0.3333
# Epoch 58/250, Train Loss: 1.9240, Train Accuracy: 0.2711, Val Loss: 1.8952, Val Accuracy: 0.3288
# Epoch 59/250, Train Loss: 1.9172, Train Accuracy: 0.2791, Val Loss: 1.9016, Val Accuracy: 0.3082
# Epoch 60/250, Train Loss: 1.9147, Train Accuracy: 0.2797, Val Loss: 1.9007, Val Accuracy: 0.3311
# Epoch 61/250, Train Loss: 1.9166, Train Accuracy: 0.2791, Val Loss: 1.8873, Val Accuracy: 0.3356
# Validation loss improved from 1.8886 to 1.8873. Saving model...
# Epoch 62/250, Train Loss: 1.9182, Train Accuracy: 0.2751, Val Loss: 1.9003, Val Accuracy: 0.3265
# Epoch 63/250, Train Loss: 1.9132, Train Accuracy: 0.2768, Val Loss: 1.9046, Val Accuracy: 0.3059
# Epoch 64/250, Train Loss: 1.9163, Train Accuracy: 0.2757, Val Loss: 1.8987, Val Accuracy: 0.3242
# Epoch 65/250, Train Loss: 1.9188, Train Accuracy: 0.2751, Val Loss: 1.8993, Val Accuracy: 0.3196
# Epoch 66/250, Train Loss: 1.9178, Train Accuracy: 0.2763, Val Loss: 1.8981, Val Accuracy: 0.3196
# Epoch 67/250, Train Loss: 1.9213, Train Accuracy: 0.2745, Val Loss: 1.9066, Val Accuracy: 0.3219
# Epoch 68/250, Train Loss: 1.9170, Train Accuracy: 0.2780, Val Loss: 1.8980, Val Accuracy: 0.3242
# Epoch 69/250, Train Loss: 1.9148, Train Accuracy: 0.2745, Val Loss: 1.9042, Val Accuracy: 0.3242
# Epoch 70/250, Train Loss: 1.9168, Train Accuracy: 0.2785, Val Loss: 1.8970, Val Accuracy: 0.3333
# Epoch 71/250, Train Loss: 1.9167, Train Accuracy: 0.2751, Val Loss: 1.8976, Val Accuracy: 0.3288
# Epoch 72/250, Train Loss: 1.9141, Train Accuracy: 0.2768, Val Loss: 1.8975, Val Accuracy: 0.3265
# Epoch 73/250, Train Loss: 1.9175, Train Accuracy: 0.2745, Val Loss: 1.9026, Val Accuracy: 0.3196
# Epoch 74/250, Train Loss: 1.9152, Train Accuracy: 0.2814, Val Loss: 1.8961, Val Accuracy: 0.3288
# Epoch 75/250, Train Loss: 1.9146, Train Accuracy: 0.2808, Val Loss: 1.9003, Val Accuracy: 0.3242
# Epoch 76/250, Train Loss: 1.9157, Train Accuracy: 0.2785, Val Loss: 1.9054, Val Accuracy: 0.3151
# Epoch 77/250, Train Loss: 1.9140, Train Accuracy: 0.2763, Val Loss: 1.9106, Val Accuracy: 0.3151
# Epoch 78/250, Train Loss: 1.9087, Train Accuracy: 0.2700, Val Loss: 1.8939, Val Accuracy: 0.3242
# Epoch 79/250, Train Loss: 1.9101, Train Accuracy: 0.2797, Val Loss: 1.9019, Val Accuracy: 0.3242
# Epoch 80/250, Train Loss: 1.9106, Train Accuracy: 0.2797, Val Loss: 1.9002, Val Accuracy: 0.3288
# Epoch 81/250, Train Loss: 1.9125, Train Accuracy: 0.2785, Val Loss: 1.9079, Val Accuracy: 0.3311
# Epoch 82/250, Train Loss: 1.9154, Train Accuracy: 0.2768, Val Loss: 1.9005, Val Accuracy: 0.3288
# Epoch 83/250, Train Loss: 1.9148, Train Accuracy: 0.2780, Val Loss: 1.8986, Val Accuracy: 0.3356
# Epoch 84/250, Train Loss: 1.9134, Train Accuracy: 0.2711, Val Loss: 1.9096, Val Accuracy: 0.3196
# Epoch 85/250, Train Loss: 1.9121, Train Accuracy: 0.2694, Val Loss: 1.8993, Val Accuracy: 0.3311
# Epoch 86/250, Train Loss: 1.9061, Train Accuracy: 0.2797, Val Loss: 1.9040, Val Accuracy: 0.3265
# Epoch 87/250, Train Loss: 1.9130, Train Accuracy: 0.2791, Val Loss: 1.8990, Val Accuracy: 0.3265
# Epoch 88/250, Train Loss: 1.9108, Train Accuracy: 0.2740, Val Loss: 1.8980, Val Accuracy: 0.3174
# Epoch 89/250, Train Loss: 1.9098, Train Accuracy: 0.2825, Val Loss: 1.9048, Val Accuracy: 0.3288
# Epoch 90/250, Train Loss: 1.9065, Train Accuracy: 0.2803, Val Loss: 1.9030, Val Accuracy: 0.3128
# Epoch 91/250, Train Loss: 1.9103, Train Accuracy: 0.2768, Val Loss: 1.9152, Val Accuracy: 0.3082
# Epoch 92/250, Train Loss: 1.9184, Train Accuracy: 0.2660, Val Loss: 1.9032, Val Accuracy: 0.3151
# Epoch 93/250, Train Loss: 1.9119, Train Accuracy: 0.2705, Val Loss: 1.9109, Val Accuracy: 0.2945
# Epoch 94/250, Train Loss: 1.9105, Train Accuracy: 0.2768, Val Loss: 1.9058, Val Accuracy: 0.3151
# Epoch 95/250, Train Loss: 1.9068, Train Accuracy: 0.2723, Val Loss: 1.9036, Val Accuracy: 0.3219
# Epoch 96/250, Train Loss: 1.9040, Train Accuracy: 0.2814, Val Loss: 1.9022, Val Accuracy: 0.3311
# Epoch 97/250, Train Loss: 1.9066, Train Accuracy: 0.2683, Val Loss: 1.9047, Val Accuracy: 0.3219
# Epoch 98/250, Train Loss: 1.9036, Train Accuracy: 0.2694, Val Loss: 1.8985, Val Accuracy: 0.3288
# Epoch 99/250, Train Loss: 1.9066, Train Accuracy: 0.2785, Val Loss: 1.8915, Val Accuracy: 0.3333
# Epoch 100/250, Train Loss: 1.9092, Train Accuracy: 0.2763, Val Loss: 1.9013, Val Accuracy: 0.3059
# Epoch 101/250, Train Loss: 1.9091, Train Accuracy: 0.2763, Val Loss: 1.9043, Val Accuracy: 0.3265
# Epoch 102/250, Train Loss: 1.9089, Train Accuracy: 0.2694, Val Loss: 1.8873, Val Accuracy: 0.3288
# Epoch 103/250, Train Loss: 1.9078, Train Accuracy: 0.2745, Val Loss: 1.8877, Val Accuracy: 0.3356
# Epoch 104/250, Train Loss: 1.9079, Train Accuracy: 0.2734, Val Loss: 1.8910, Val Accuracy: 0.3288
# Epoch 105/250, Train Loss: 1.9046, Train Accuracy: 0.2791, Val Loss: 1.8955, Val Accuracy: 0.3356
# Epoch 106/250, Train Loss: 1.9064, Train Accuracy: 0.2785, Val Loss: 1.8911, Val Accuracy: 0.3379
# Epoch 107/250, Train Loss: 1.9118, Train Accuracy: 0.2740, Val Loss: 1.9085, Val Accuracy: 0.3242
# Epoch 108/250, Train Loss: 1.9085, Train Accuracy: 0.2757, Val Loss: 1.9051, Val Accuracy: 0.3196
# Epoch 109/250, Train Loss: 1.9078, Train Accuracy: 0.2734, Val Loss: 1.9012, Val Accuracy: 0.3196
# Epoch 110/250, Train Loss: 1.9125, Train Accuracy: 0.2774, Val Loss: 1.9117, Val Accuracy: 0.3174
# Epoch 111/250, Train Loss: 1.9080, Train Accuracy: 0.2774, Val Loss: 1.9087, Val Accuracy: 0.3242
# Epoch 112/250, Train Loss: 1.9122, Train Accuracy: 0.2694, Val Loss: 1.8992, Val Accuracy: 0.3288
# Epoch 113/250, Train Loss: 1.9078, Train Accuracy: 0.2780, Val Loss: 1.8973, Val Accuracy: 0.3242
# Epoch 114/250, Train Loss: 1.9022, Train Accuracy: 0.2751, Val Loss: 1.8989, Val Accuracy: 0.3311
# Epoch 115/250, Train Loss: 1.9005, Train Accuracy: 0.2717, Val Loss: 1.9045, Val Accuracy: 0.3288
# Epoch 116/250, Train Loss: 1.9058, Train Accuracy: 0.2751, Val Loss: 1.9021, Val Accuracy: 0.3288
# Epoch 117/250, Train Loss: 1.8996, Train Accuracy: 0.2774, Val Loss: 1.8973, Val Accuracy: 0.3265
# Epoch 118/250, Train Loss: 1.9017, Train Accuracy: 0.2808, Val Loss: 1.9065, Val Accuracy: 0.3196
# Epoch 119/250, Train Loss: 1.9024, Train Accuracy: 0.2757, Val Loss: 1.9035, Val Accuracy: 0.3333
# Epoch 120/250, Train Loss: 1.9030, Train Accuracy: 0.2700, Val Loss: 1.9057, Val Accuracy: 0.3288
# Epoch 121/250, Train Loss: 1.9019, Train Accuracy: 0.2751, Val Loss: 1.9155, Val Accuracy: 0.3242
# Epoch 122/250, Train Loss: 1.9014, Train Accuracy: 0.2751, Val Loss: 1.8901, Val Accuracy: 0.3402
# Epoch 123/250, Train Loss: 1.9055, Train Accuracy: 0.2751, Val Loss: 1.9068, Val Accuracy: 0.3242
# Epoch 124/250, Train Loss: 1.9052, Train Accuracy: 0.2757, Val Loss: 1.9029, Val Accuracy: 0.3311
# Epoch 125/250, Train Loss: 1.8992, Train Accuracy: 0.2768, Val Loss: 1.8990, Val Accuracy: 0.3196
# Epoch 126/250, Train Loss: 1.9009, Train Accuracy: 0.2774, Val Loss: 1.8788, Val Accuracy: 0.3311
# Validation loss improved from 1.8873 to 1.8788. Saving model...
# Epoch 127/250, Train Loss: 1.8962, Train Accuracy: 0.2780, Val Loss: 1.9064, Val Accuracy: 0.3196
# Epoch 128/250, Train Loss: 1.9044, Train Accuracy: 0.2734, Val Loss: 1.9209, Val Accuracy: 0.3151
# Epoch 129/250, Train Loss: 1.9200, Train Accuracy: 0.2551, Val Loss: 1.9069, Val Accuracy: 0.3242
# Epoch 130/250, Train Loss: 1.9146, Train Accuracy: 0.2705, Val Loss: 1.9011, Val Accuracy: 0.3311
# Epoch 131/250, Train Loss: 1.9092, Train Accuracy: 0.2740, Val Loss: 1.9051, Val Accuracy: 0.3311
# Epoch 132/250, Train Loss: 1.9080, Train Accuracy: 0.2717, Val Loss: 1.8925, Val Accuracy: 0.3311
# Epoch 133/250, Train Loss: 1.9062, Train Accuracy: 0.2745, Val Loss: 1.9027, Val Accuracy: 0.3288
# Epoch 134/250, Train Loss: 1.9062, Train Accuracy: 0.2723, Val Loss: 1.8951, Val Accuracy: 0.3288
# Epoch 135/250, Train Loss: 1.9206, Train Accuracy: 0.2700, Val Loss: 1.8933, Val Accuracy: 0.3288
# Epoch 136/250, Train Loss: 1.9100, Train Accuracy: 0.2780, Val Loss: 1.8915, Val Accuracy: 0.3265
# Epoch 137/250, Train Loss: 1.9052, Train Accuracy: 0.2785, Val Loss: 1.8979, Val Accuracy: 0.3288
# Epoch 138/250, Train Loss: 1.8996, Train Accuracy: 0.2774, Val Loss: 1.8889, Val Accuracy: 0.3311
# Epoch 139/250, Train Loss: 1.8981, Train Accuracy: 0.2780, Val Loss: 1.8909, Val Accuracy: 0.3242
# Epoch 140/250, Train Loss: 1.9007, Train Accuracy: 0.2803, Val Loss: 1.8938, Val Accuracy: 0.3242
# Epoch 141/250, Train Loss: 1.8990, Train Accuracy: 0.2745, Val Loss: 1.8960, Val Accuracy: 0.3265
# Epoch 142/250, Train Loss: 1.8970, Train Accuracy: 0.2763, Val Loss: 1.8981, Val Accuracy: 0.3265
# Epoch 143/250, Train Loss: 1.8996, Train Accuracy: 0.2814, Val Loss: 1.9062, Val Accuracy: 0.3219
# Epoch 144/250, Train Loss: 1.8953, Train Accuracy: 0.2768, Val Loss: 1.9102, Val Accuracy: 0.3288
# Epoch 145/250, Train Loss: 1.9016, Train Accuracy: 0.2854, Val Loss: 1.9076, Val Accuracy: 0.3265
# Epoch 146/250, Train Loss: 1.8998, Train Accuracy: 0.2780, Val Loss: 1.9053, Val Accuracy: 0.3288
# Epoch 147/250, Train Loss: 1.8962, Train Accuracy: 0.2825, Val Loss: 1.9099, Val Accuracy: 0.3242
# Epoch 148/250, Train Loss: 1.8978, Train Accuracy: 0.2780, Val Loss: 1.9095, Val Accuracy: 0.3242
# Epoch 149/250, Train Loss: 1.8963, Train Accuracy: 0.2814, Val Loss: 1.9049, Val Accuracy: 0.3265
# Epoch 150/250, Train Loss: 1.8981, Train Accuracy: 0.2774, Val Loss: 1.8963, Val Accuracy: 0.3311
# Epoch 151/250, Train Loss: 1.8959, Train Accuracy: 0.2797, Val Loss: 1.9087, Val Accuracy: 0.3242
# Epoch 152/250, Train Loss: 1.8982, Train Accuracy: 0.2757, Val Loss: 1.9177, Val Accuracy: 0.3265
# Epoch 153/250, Train Loss: 1.8892, Train Accuracy: 0.2814, Val Loss: 1.9118, Val Accuracy: 0.3242
# Epoch 154/250, Train Loss: 1.8960, Train Accuracy: 0.2825, Val Loss: 1.9141, Val Accuracy: 0.3219
# Epoch 155/250, Train Loss: 1.8960, Train Accuracy: 0.2757, Val Loss: 1.9104, Val Accuracy: 0.3288
# Epoch 156/250, Train Loss: 1.8894, Train Accuracy: 0.2831, Val Loss: 1.9049, Val Accuracy: 0.3265
# Epoch 157/250, Train Loss: 1.8916, Train Accuracy: 0.2831, Val Loss: 1.9149, Val Accuracy: 0.3196
# Epoch 158/250, Train Loss: 1.8929, Train Accuracy: 0.2745, Val Loss: 1.9182, Val Accuracy: 0.3151
# Epoch 159/250, Train Loss: 1.8903, Train Accuracy: 0.2785, Val Loss: 1.9157, Val Accuracy: 0.3288
# Epoch 160/250, Train Loss: 1.8923, Train Accuracy: 0.2751, Val Loss: 1.9104, Val Accuracy: 0.3265
# Epoch 161/250, Train Loss: 1.8890, Train Accuracy: 0.2808, Val Loss: 1.9015, Val Accuracy: 0.3265
# Epoch 162/250, Train Loss: 1.8906, Train Accuracy: 0.2768, Val Loss: 1.9028, Val Accuracy: 0.3219
# Epoch 163/250, Train Loss: 1.8932, Train Accuracy: 0.2705, Val Loss: 1.9067, Val Accuracy: 0.3151
# Epoch 164/250, Train Loss: 1.8905, Train Accuracy: 0.2671, Val Loss: 1.9100, Val Accuracy: 0.3128
# Epoch 165/250, Train Loss: 1.8896, Train Accuracy: 0.2808, Val Loss: 1.9073, Val Accuracy: 0.3219
# Epoch 166/250, Train Loss: 1.8948, Train Accuracy: 0.2694, Val Loss: 1.9172, Val Accuracy: 0.3242
# Epoch 167/250, Train Loss: 1.8898, Train Accuracy: 0.2734, Val Loss: 1.9072, Val Accuracy: 0.3356
# Epoch 168/250, Train Loss: 1.9012, Train Accuracy: 0.2734, Val Loss: 1.9104, Val Accuracy: 0.3311
# Epoch 169/250, Train Loss: 1.8973, Train Accuracy: 0.2763, Val Loss: 1.9071, Val Accuracy: 0.3196
# Epoch 170/250, Train Loss: 1.8975, Train Accuracy: 0.2791, Val Loss: 1.9047, Val Accuracy: 0.3219
# Epoch 171/250, Train Loss: 1.8973, Train Accuracy: 0.2848, Val Loss: 1.9099, Val Accuracy: 0.3242
# Epoch 172/250, Train Loss: 1.8906, Train Accuracy: 0.2814, Val Loss: 1.9067, Val Accuracy: 0.3128
# Epoch 173/250, Train Loss: 1.8828, Train Accuracy: 0.2825, Val Loss: 1.9080, Val Accuracy: 0.3219
# Epoch 174/250, Train Loss: 1.8897, Train Accuracy: 0.2751, Val Loss: 1.9077, Val Accuracy: 0.3265
# Epoch 175/250, Train Loss: 1.8886, Train Accuracy: 0.2774, Val Loss: 1.9111, Val Accuracy: 0.3037
# Epoch 176/250, Train Loss: 1.8906, Train Accuracy: 0.2745, Val Loss: 1.8979, Val Accuracy: 0.3242
# Epoch 177/250, Train Loss: 1.8906, Train Accuracy: 0.2825, Val Loss: 1.9178, Val Accuracy: 0.3014
# Epoch 178/250, Train Loss: 1.8924, Train Accuracy: 0.2797, Val Loss: 1.9158, Val Accuracy: 0.3082
# Epoch 179/250, Train Loss: 1.8822, Train Accuracy: 0.2814, Val Loss: 1.9061, Val Accuracy: 0.3196
# Epoch 180/250, Train Loss: 1.8882, Train Accuracy: 0.2808, Val Loss: 1.9060, Val Accuracy: 0.3174
# Epoch 181/250, Train Loss: 1.8842, Train Accuracy: 0.2791, Val Loss: 1.9135, Val Accuracy: 0.3037
# Epoch 182/250, Train Loss: 1.8826, Train Accuracy: 0.2894, Val Loss: 1.9091, Val Accuracy: 0.3219
# Epoch 183/250, Train Loss: 1.8819, Train Accuracy: 0.2745, Val Loss: 1.9124, Val Accuracy: 0.3151
# Epoch 184/250, Train Loss: 1.8808, Train Accuracy: 0.2728, Val Loss: 1.9183, Val Accuracy: 0.3174
# Epoch 185/250, Train Loss: 1.8796, Train Accuracy: 0.2763, Val Loss: 1.9098, Val Accuracy: 0.2991
# Epoch 186/250, Train Loss: 1.8771, Train Accuracy: 0.2763, Val Loss: 1.9155, Val Accuracy: 0.3105
# Epoch 187/250, Train Loss: 1.8769, Train Accuracy: 0.2865, Val Loss: 1.9104, Val Accuracy: 0.3174
# Epoch 188/250, Train Loss: 1.8790, Train Accuracy: 0.2820, Val Loss: 1.9097, Val Accuracy: 0.3082
# Epoch 189/250, Train Loss: 1.8858, Train Accuracy: 0.2780, Val Loss: 1.9102, Val Accuracy: 0.3105
# Epoch 190/250, Train Loss: 1.8817, Train Accuracy: 0.2785, Val Loss: 1.9076, Val Accuracy: 0.3196
# Epoch 191/250, Train Loss: 1.8756, Train Accuracy: 0.2820, Val Loss: 1.9150, Val Accuracy: 0.3151
# Epoch 192/250, Train Loss: 1.8772, Train Accuracy: 0.2860, Val Loss: 1.9732, Val Accuracy: 0.3174
# Epoch 193/250, Train Loss: 1.9098, Train Accuracy: 0.2734, Val Loss: 1.9337, Val Accuracy: 0.3196
# Epoch 194/250, Train Loss: 1.8993, Train Accuracy: 0.2911, Val Loss: 1.9353, Val Accuracy: 0.3174
# Epoch 195/250, Train Loss: 1.8955, Train Accuracy: 0.2877, Val Loss: 1.9307, Val Accuracy: 0.3128
# Epoch 196/250, Train Loss: 1.8949, Train Accuracy: 0.2871, Val Loss: 1.9295, Val Accuracy: 0.3082
# Epoch 197/250, Train Loss: 1.8939, Train Accuracy: 0.2825, Val Loss: 1.9252, Val Accuracy: 0.3082
# Epoch 198/250, Train Loss: 1.8890, Train Accuracy: 0.2842, Val Loss: 1.9361, Val Accuracy: 0.2877
# Epoch 199/250, Train Loss: 1.8862, Train Accuracy: 0.2757, Val Loss: 1.9264, Val Accuracy: 0.3082
# Epoch 200/250, Train Loss: 1.8876, Train Accuracy: 0.2848, Val Loss: 1.9235, Val Accuracy: 0.2968
# Epoch 201/250, Train Loss: 1.8913, Train Accuracy: 0.2825, Val Loss: 1.9152, Val Accuracy: 0.3151
# Epoch 202/250, Train Loss: 1.8949, Train Accuracy: 0.2808, Val Loss: 1.9225, Val Accuracy: 0.3174
# Epoch 203/250, Train Loss: 1.8917, Train Accuracy: 0.2854, Val Loss: 1.9118, Val Accuracy: 0.3219
# Epoch 204/250, Train Loss: 1.8848, Train Accuracy: 0.2871, Val Loss: 1.9153, Val Accuracy: 0.3196
# Epoch 205/250, Train Loss: 1.8807, Train Accuracy: 0.2854, Val Loss: 1.9145, Val Accuracy: 0.3059
# Epoch 206/250, Train Loss: 1.8831, Train Accuracy: 0.2865, Val Loss: 1.9304, Val Accuracy: 0.3174
# Epoch 207/250, Train Loss: 1.8877, Train Accuracy: 0.2860, Val Loss: 1.9115, Val Accuracy: 0.3196
# Epoch 208/250, Train Loss: 1.8808, Train Accuracy: 0.2854, Val Loss: 1.9083, Val Accuracy: 0.3242
# Epoch 209/250, Train Loss: 1.8791, Train Accuracy: 0.2888, Val Loss: 1.9221, Val Accuracy: 0.3196
# Epoch 210/250, Train Loss: 1.8780, Train Accuracy: 0.2882, Val Loss: 1.9188, Val Accuracy: 0.3105
# Epoch 211/250, Train Loss: 1.8786, Train Accuracy: 0.2939, Val Loss: 1.9273, Val Accuracy: 0.3059
# Epoch 212/250, Train Loss: 1.8821, Train Accuracy: 0.2865, Val Loss: 1.9201, Val Accuracy: 0.3105
# Epoch 213/250, Train Loss: 1.8789, Train Accuracy: 0.2865, Val Loss: 1.9202, Val Accuracy: 0.3105
# Epoch 214/250, Train Loss: 1.8771, Train Accuracy: 0.2917, Val Loss: 1.9209, Val Accuracy: 0.3105
# Epoch 215/250, Train Loss: 1.8805, Train Accuracy: 0.2877, Val Loss: 1.9199, Val Accuracy: 0.3037
# Epoch 216/250, Train Loss: 1.8955, Train Accuracy: 0.2803, Val Loss: 1.9298, Val Accuracy: 0.3128
# Epoch 217/250, Train Loss: 1.8868, Train Accuracy: 0.2814, Val Loss: 1.9158, Val Accuracy: 0.3128
# Epoch 218/250, Train Loss: 1.8824, Train Accuracy: 0.2820, Val Loss: 1.9190, Val Accuracy: 0.3174
# Epoch 219/250, Train Loss: 1.8764, Train Accuracy: 0.2814, Val Loss: 1.9171, Val Accuracy: 0.3037
# Epoch 220/250, Train Loss: 1.8725, Train Accuracy: 0.2894, Val Loss: 1.9139, Val Accuracy: 0.3219
# Epoch 221/250, Train Loss: 1.8766, Train Accuracy: 0.2877, Val Loss: 1.9159, Val Accuracy: 0.3105
# Epoch 222/250, Train Loss: 1.8751, Train Accuracy: 0.2865, Val Loss: 1.9194, Val Accuracy: 0.3082
# Epoch 223/250, Train Loss: 1.8836, Train Accuracy: 0.2848, Val Loss: 1.9236, Val Accuracy: 0.2968
# Epoch 224/250, Train Loss: 1.8749, Train Accuracy: 0.2848, Val Loss: 1.9251, Val Accuracy: 0.2991
# Epoch 225/250, Train Loss: 1.8716, Train Accuracy: 0.2922, Val Loss: 1.9129, Val Accuracy: 0.3196
# Epoch 226/250, Train Loss: 1.8739, Train Accuracy: 0.2945, Val Loss: 1.9189, Val Accuracy: 0.3059
# Epoch 227/250, Train Loss: 1.8734, Train Accuracy: 0.2905, Val Loss: 1.9195, Val Accuracy: 0.3174
# Epoch 228/250, Train Loss: 1.8781, Train Accuracy: 0.2928, Val Loss: 1.9223, Val Accuracy: 0.3151
# Epoch 229/250, Train Loss: 1.8772, Train Accuracy: 0.2900, Val Loss: 1.9419, Val Accuracy: 0.3037
# Epoch 230/250, Train Loss: 1.8758, Train Accuracy: 0.2871, Val Loss: 1.9252, Val Accuracy: 0.3105
# Epoch 231/250, Train Loss: 1.8714, Train Accuracy: 0.2894, Val Loss: 1.9246, Val Accuracy: 0.3151
# Epoch 232/250, Train Loss: 1.8774, Train Accuracy: 0.2837, Val Loss: 1.9390, Val Accuracy: 0.3105
# Epoch 233/250, Train Loss: 1.9029, Train Accuracy: 0.2785, Val Loss: 1.9181, Val Accuracy: 0.3242
# Epoch 234/250, Train Loss: 1.8878, Train Accuracy: 0.2808, Val Loss: 1.9534, Val Accuracy: 0.3037
# Epoch 235/250, Train Loss: 1.8939, Train Accuracy: 0.2791, Val Loss: 1.9396, Val Accuracy: 0.2991
# Epoch 236/250, Train Loss: 1.8779, Train Accuracy: 0.2785, Val Loss: 1.9216, Val Accuracy: 0.2991
# Epoch 237/250, Train Loss: 1.8856, Train Accuracy: 0.2745, Val Loss: 1.9159, Val Accuracy: 0.2831
# Epoch 238/250, Train Loss: 1.8805, Train Accuracy: 0.2763, Val Loss: 1.9219, Val Accuracy: 0.3105
# Epoch 239/250, Train Loss: 1.8791, Train Accuracy: 0.2768, Val Loss: 1.9261, Val Accuracy: 0.3128
# Epoch 240/250, Train Loss: 1.8744, Train Accuracy: 0.2860, Val Loss: 1.9203, Val Accuracy: 0.3014
# Epoch 241/250, Train Loss: 1.8725, Train Accuracy: 0.2945, Val Loss: 1.9192, Val Accuracy: 0.3151
# Epoch 242/250, Train Loss: 1.8755, Train Accuracy: 0.2928, Val Loss: 1.9255, Val Accuracy: 0.3014
# Epoch 243/250, Train Loss: 1.8734, Train Accuracy: 0.2894, Val Loss: 1.9296, Val Accuracy: 0.3037
# Epoch 244/250, Train Loss: 1.8710, Train Accuracy: 0.2865, Val Loss: 1.9225, Val Accuracy: 0.3174
# Epoch 245/250, Train Loss: 1.8777, Train Accuracy: 0.2837, Val Loss: 1.9248, Val Accuracy: 0.3037
# Epoch 246/250, Train Loss: 1.8873, Train Accuracy: 0.2808, Val Loss: 1.9016, Val Accuracy: 0.3082
# Epoch 247/250, Train Loss: 1.8886, Train Accuracy: 0.2774, Val Loss: 1.9026, Val Accuracy: 0.3311
# Epoch 248/250, Train Loss: 1.8857, Train Accuracy: 0.2894, Val Loss: 1.9103, Val Accuracy: 0.3288
# Epoch 249/250, Train Loss: 1.8796, Train Accuracy: 0.2831, Val Loss: 1.9100, Val Accuracy: 0.3311
# Epoch 250/250, Train Loss: 1.8854, Train Accuracy: 0.2842, Val Loss: 1.9056, Val Accuracy: 0.3333
